# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("house_price_regression_dataset.csv")
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
df.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
df.tail()
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality    House_Price
# 995            2                    10  701493.997069
# 996            1                    10  683723.160704
# 997            0                     2  572024.023634
# 998            0                     7  964865.298639
# 999            2                     2  742599.253332

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
df.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built     Lot_Size  \
# count     1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean      2815.422000      2.990000       1.973000  1986.550000     2.778087
# std       1255.514921      1.427564       0.820332    20.632916     1.297903
# min        503.000000      1.000000       1.000000  1950.000000     0.506058
# 25%       1749.500000      2.000000       1.000000  1969.000000     1.665946
# 50%       2862.500000      3.000000       2.000000  1986.000000     2.809740
# 75%       3849.500000      4.000000       3.000000  2004.250000     3.923317
# max       4999.000000      5.000000       3.000000  2022.000000     4.989303
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count  1000.000000           1000.000000  1.000000e+03
# mean      1.022000              5.615000  6.188610e+05
# std       0.814973              2.887059  2.535681e+05
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x='House_Price',y='Square_Footage',data=df,kind='reg')

# %%
sns.swarmplot(x='Num_Bathrooms',y='House_Price',data=df)
# Out:
# <Axes: xlabel='Num_Bathrooms', ylabel='House_Price'>

# %%
sns.set_palette("pastel")
sns.barplot(x="Neighborhood_Quality", y="House_Price", hue="Num_Bathrooms", data=df)
# Out:
# <Axes: xlabel='Neighborhood_Quality', ylabel='House_Price'>

# %%
sns.displot(df['Year_Built'])
plt.xticks(rotation=45)
# Out:
# (array([1940., 1950., 1960., 1970., 1980., 1990., 2000., 2010., 2020.,
#         2030.]),
#  [Text(1940.0, 0, '1940'),
#   Text(1950.0, 0, '1950'),
#   Text(1960.0, 0, '1960'),
#   Text(1970.0, 0, '1970'),
#   Text(1980.0, 0, '1980'),
#   Text(1990.0, 0, '1990'),
#   Text(2000.0, 0, '2000'),
#   Text(2010.0, 0, '2010'),
#   Text(2020.0, 0, '2020'),
#   Text(2030.0, 0, '2030')])

# %%
sns.jointplot(x='Garage_Size',y='House_Price',data=df,kind='hex')

# %%
sns.boxplot(data=df,palette='rainbow')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Square_Footage'),
#   Text(1, 0, 'Num_Bedrooms'),
#   Text(2, 0, 'Num_Bathrooms'),
#   Text(3, 0, 'Year_Built'),
#   Text(4, 0, 'Lot_Size'),
#   Text(5, 0, 'Garage_Size'),
#   Text(6, 0, 'Neighborhood_Quality'),
#   Text(7, 0, 'House_Price')])

# %%
columns=df.columns

# %%
correlation_matrix=df.corr()
print(correlation_matrix)
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage              1.000000     -0.043564      -0.031584   -0.022392
# Num_Bedrooms               -0.043564      1.000000       0.022848   -0.015820
# Num_Bathrooms              -0.031584      0.022848       1.000000   -0.021063
# Year_Built                 -0.022392     -0.015820      -0.021063    1.000000
# Lot_Size                    0.089479     -0.009355       0.034923   -0.061050
# Garage_Size                 0.030593      0.113761       0.024846   -0.025485
# Neighborhood_Quality       -0.008357     -0.049024       0.017585   -0.009549
# House_Price                 0.991261      0.014633      -0.001862    0.051967
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage        0.089479     0.030593             -0.008357     0.991261
# Num_Bedrooms         -0.009355     0.113761             -0.049024     0.014633
# ...

# %%
sns.heatmap(correlation_matrix,cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df=sc.fit_transform(df)

# %%
df=pd.DataFrame(data=df,columns=columns)

# %%
x=df.drop('House_Price',axis=1)
y=df['House_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Coefficients:", model.coef_)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Coefficients: [0.98786834 0.05756691 0.02655555 0.08084444 0.07619172 0.01653982
#  0.00131014]
# Mean Squared Error: 0.0015791827532208292
# R-squared Score: 0.9984263636823413
